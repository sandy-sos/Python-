# %%
print(1)
# Out:
# 1

# %%
print(1,2,3,4)
print(1,2,3,4,sep="  ")
# Out:
# 1 2 3 4
# 1  2  3  4

# %%
print(1,2,3,end="\n")
print(4,5,6)
# Out:
# 1 2 3
# 4 5 6

# %%
with open("测试.txt",'a') as f:
    print("f是执行后自动关闭,a是保留文件内容在后面添加,w是覆盖",file=f)

# %%
print("我的名字是%s,年龄是%d岁"% ("001",11))

print('我的名字是{},年龄是{}岁' .format ("001",11))

name,age="222",18
print(f"名字是{name},年龄是{age}")
# Out:
# 我的名字是001,年龄是11岁
# 我的名字是001,年龄是11岁
# 名字是222,年龄是18

# %%
a=input("输入：")
print("输入的内容是：",a) #字符串类型

a=int(input("输入："))
print("输入的内容是：",a) #强制转换
# Out:
# 输入的内容是： 3
# 输入的内容是： 1
